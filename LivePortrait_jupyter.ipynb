# %% [markdown]
# <a href="https://colab.research.google.com/github/sindhu-2211/Blogging/blob/main/LivePortrait_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  LivePortrait Code Optimization for IntellifAI Labs Assignment
#
# This notebook demonstrates the original and optimized inference process using the [LivePortrait](https://github.com/KwaiVGI/LivePortrait) repository.
# The objective is to reduce inference time, and optionally improve output quality and GPU memory usage.

# %% [markdown]
# #Setup & Installation (Code Cell)
# Install dependencies, clone the repo, and set up the environment.

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/LivePortrait
# %cd /content/LivePortrait

# !rm -rf /content/LivePortrait/pretrained_weights
# !git clone https://huggingface.co/camenduru/LivePortrait /content/LivePortrait/pretrained_weights

# !pip install tyro==0.8.5 onnxruntime-gpu==1.18.1 onnx==1.16.1 gradio==4.36.1 colorama

# %cd /content/LivePortrait/src/utils/dependencies/insightface/thirdparty/face3d/mesh/cython
# !python setup.py build_ext --inplace
# Out:
# /content
# fatal: destination path 'LivePortrait' already exists and is not an empty directory.
# /content/LivePortrait
# Cloning into '/content/LivePortrait/pretrained_weights'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 19 (delta 0), reused 0 (delta 0), pack-reused 3 (from 1)
# Unpacking objects: 100% (19/19), 3.49 KiB | 1.16 MiB/s, done.
# Filtering content: 100% (8/8), 628.42 MiB | 51.89 MiB/s, done.
# ...
# /content/LivePortrait/src/utils/dependencies/insightface/thirdparty/face3d/mesh/cython

# %%
# %cd /content/LivePortrait
# !python inference.py -s /content/LivePortrait/assets/examples/source/s7.jpg -d /content/LivePortrait/assets/examples/driving/d7.mp4
# Out:
# /content/LivePortrait
# [01:13:03] Load appearance_feature_extractor done.   ]8;id=815514;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=576356;file:///content/LivePortrait/src/live_portrait_wrapper.py#30\30]8;;\
# [01:13:04] Load motion_extractor done.               ]8;id=474510;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=997424;file:///content/LivePortrait/src/live_portrait_wrapper.py#33\33]8;;\
#            Load warping_module done.                 ]8;id=782079;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=724304;file:///content/LivePortrait/src/live_portrait_wrapper.py#36\36]8;;\
# [01:13:05] Load spade_generator done.                ]8;id=176234;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=67582;file:///content/LivePortrait/src/live_portrait_wrapper.py#39\39]8;;\
# ...

# %%
from IPython.display import Video

# Replace with your actual output video path
video_path = '/content/LivePortrait/animations/s7--d7_concat.mp4'

Video(video_path, embed=True, width=640, height=480)
# Out:
# <video controls  width="640"  height="480">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%time
# !python inference.py -s /content/LivePortrait/assets/examples/source/s7.jpg -d /content/LivePortrait/assets/examples/driving/d7.mp4
# Out:
# [01:17:55] Load appearance_feature_extractor done.   ]8;id=868354;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=670153;file:///content/LivePortrait/src/live_portrait_wrapper.py#30\30]8;;\
#            Load motion_extractor done.               ]8;id=182327;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=47104;file:///content/LivePortrait/src/live_portrait_wrapper.py#33\33]8;;\
# [01:17:56] Load warping_module done.                 ]8;id=870992;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=936549;file:///content/LivePortrait/src/live_portrait_wrapper.py#36\36]8;;\
#            Load spade_generator done.                ]8;id=444572;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=892646;file:///content/LivePortrait/src/live_portrait_wrapper.py#39\39]8;;\
# ...

# %%
# !python speed.py
# Out:
# Warm up start!
# Warm up end!
# Number of parameters for Appearance Feature Extractor: 0.84 M
# Number of parameters for Motion Extractor: 28.12 M
# Number of parameters for Warping Network: 45.53 M
# Number of parameters for SPADE Decoder: 55.37 M
# Number of parameters for part_0 in Stitching and Retargeting Modules: 0.05 M
# Number of parameters for part_1 in Stitching and Retargeting Modules: 0.14 M
# Number of parameters for part_2 in Stitching and Retargeting Modules: 0.04 M
# Average inference time for Appearance Feature Extractor over 100 runs: 6.41 ms (std: 0.14 ms)
# Average inference time for Motion Extractor over 100 runs: 3.26 ms (std: 0.16 ms)
# Average inference time for Warping Network over 100 runs: 38.21 ms (std: 0.47 ms)
# Average inference time for SPADE Decoder over 100 runs: 41.27 ms (std: 0.60 ms)
# Average inference time for Retargeting Models over 100 runs: 0.73 ms (std: 0.17 ms)

# %%
#optimised

# %%
cd /content/LivePortrait
# Out:
# /content/LivePortrait

# %%
# !python  optimised_inference.py -s /content/LivePortrait/assets/examples/source/s7.jpg -d /content/LivePortrait/assets/examples/driving/d7.mp4
# Out:
# 🎭 LivePortrait - Advanced Optimized Version
# 🔧 Configuration: compile_mode=max-autotune, fp16=True
# 🚀 Applying targeted optimizations...
# ✅ TF32 disabled for older GPU
# ✅ Flash Attention enabled
# ✅ GPU: Tesla T4
# ✅ Targeted optimizations applied
# 📦 Loading pipeline...
# [02:36:42] Load appearance_feature_extractor done.   ]8;id=701088;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=88598;file:///content/LivePortrait/src/live_portrait_wrapper.py#30\30]8;;\
# [02:36:43] Load motion_extractor done.               ]8;id=410635;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=171244;file:///content/LivePortrait/src/live_portrait_wrapper.py#33\33]8;;\
#            Load warping_module done.                 ]8;id=739708;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=124303;file:///content/LivePortrait/src/live_portrait_wrapper.py#36\36]8;;\
# ...

# %%
from IPython.display import Video

# Replace with your actual output video path
video_path = '/content/LivePortrait/animations/s7--d7_concat.mp4'

Video(video_path, embed=True, width=640, height=480)
# Out:
# <video controls  width="640"  height="480">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# !python optimised_speed.py
# Out:
# 🎭 LivePortrait Optimized Speed Benchmark
# 🚀 Applying optimizations for benchmarking...
# ✅ GPU: Tesla T4
# ✅ Optimizations applied
# 📦 Loading models with optimizations...
# ✅ Models loaded and optimized
# 🔥 Extended warm up for optimized models...
#    Warm-up iteration 1/20
#    Warm-up iteration 6/20
#    Warm-up iteration 11/20
#    Warm-up iteration 16/20
# ✅ Extended warm up completed
# 📊 Measuring inference times over 100 runs...
#    Progress: 1/100
#    Progress: 21/100
#    Progress: 41/100
#    Progress: 61/100
#    Progress: 81/100
#
# ...
# 🚀 OPTIMIZED LIVEPORTRAIT BENCHMARK RESULTS
# ...
#
# 📦 MODEL PARAMETERS:
#    Appearance Feature Extractor: 0.84M parameters
#    Motion Extractor: 28.12M parameters
#    Warping Network: 45.53M parameters
#    SPADE Decoder: 55.37M parameters
#    Retargeting stitching: 0.05M parameters
#    Retargeting eye: 0.14M parameters
#    Retargeting lip: 0.04M parameters
#    TOTAL: 130.08M parameters
#
# ⏱️  INFERENCE TIMES (averaged over 100 runs):
# ...
